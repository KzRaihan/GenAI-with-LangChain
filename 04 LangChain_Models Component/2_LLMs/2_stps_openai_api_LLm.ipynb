# %% [markdown]
# ## Topic: Use Openai model for

# %% [markdown]
# - Step_1: Create an account
#     - https://platform.openai.com/home
#
# - Step_2: Create an new secret key
#
# - Step_3: Store Secret key into
#     - .env file

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env
load_dotenv()

# Check whether the API key is available
print("API key loaded:", bool(os.getenv("OPENAI_API_KEY")))
# Out:
# API key loaded: True

# %%
# STEP 1: Import Required Libraries
from langchain_openai import OpenAI
from dotenv import load_dotenv


# Load environment variables from .env
load_dotenv()  


# STEP 2: Create OpenAI LLM
llm = OpenAI(model= "gpt-3.5-turbo-instruct")

response  = llm.invoke("What is the capital of Bangladesh?")

print(response)

# %% [markdown]
# - Key Note:
#     - OpenAI class inheritance ->  BaseOpenAI class
#     - BaseOpenAI inheritance  -> BaseLLM class
#     - BaseLLM inheritance ->  BaseLanguageModel class
#     - BaseLanguageModel inheritance ->  BaseLanguageModel class
