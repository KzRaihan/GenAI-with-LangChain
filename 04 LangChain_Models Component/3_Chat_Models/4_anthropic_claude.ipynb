# %% [markdown]
# ## Topic: We Explain the Anthropic -> claude Chat Model

# %% [markdown]
# - Step1: Create an API Key
#     - websitelink: https://platform.claude.com/create
#
# - step2: To specific the model
#     - website: https://platform.claude.com/docs/en/models/overview

# %%
from langchain_anthropic import ChatAnthropic
from dotenv import load_dotenv

# Load environment variables from .env
load_dotenv()

# initialize the ChatAnthropic model
model = ChatAnthropic(
    model = "claude-fable-5-1",

   
)

# Invoke the model with a prompt
response = model.invoke("What is Python programming language?")

print("Response from the model:", response.content)
