# %% [markdown]
# ## Topic: Google Gemini Model

# %% [markdown]
# - Step1: Go to the and Create an google api key
#     - https://ai.google.dev/
#
#     - https://ai.google.dev/gemini-api/docs/api-key
