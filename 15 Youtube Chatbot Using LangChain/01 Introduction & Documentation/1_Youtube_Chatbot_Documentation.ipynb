# %% [markdown]
# ## Topic: YouTube RAG Chatbot — Project Documentation

# %% [markdown]
# ### Agenda
# - 1. Problem Statement
#
# - 2. Objective of the Project

# %% [markdown]
# ### 1. Problem Statement
#
# - Youtube RAW Chatbot:
#     - if i want to quick answer of a video then it is not possible because Youtube video are so long and if we see a video that have no answer or information then our time is wastage.

# %% [markdown]
# ### 2. Objective of the Project
#
# - Objective of Youtube RAW Chatbot:
#     - Create a Youtube RAG Chatbot System, so that you can chart the Chatbot in real time and get the correct answer according to your question.
#
#     - you just only paste the youtube url or id then our Chatbot automatically give you the correct answer.
#
#
# - Key note:
#     - if the answer is not available in the video, then our chatbot can't hallucination or can't give the incorrect answer.
