# %% [markdown]
# ## Topic: GenAI Roadmap with LangChain

# %% [markdown]
# ### LangChain Roadmap
#
# - 1. Fundamentals of LangChain
#     - 1.1: What is LangChain?
#     - 1.2: LangChain Components
#     - 1.3: Models
#     - 1.4: Prompt
#     - 1.5: Parsing output
#     - 1.6: Runnables and LCEL
#     - 1.7: Chains
#     - 1.8: Memory
#
# - 2. RAG
#     - 2.1: Document Loaders
#     - 2.2: Text Splitters
#     - 2.3: Embeddings
#     - 2.4: Vector Stores
#     - 2.5: Retrievers
#     - 2.6: Building a RAG application
#
# - 3. Agents
#     - 3.1: Tools and Toolkits
#     - 3.2: Tool calling
#     - 3.3: Building an Al agent
