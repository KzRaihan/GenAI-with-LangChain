# %% [markdown]
# ## Topic: Ollama with LangChain

# %% [markdown]
# ### Agenda
# - 1. Which Model is best for work with langchain + RAW  application?

# %% [markdown]
# ### 1. Which Model is best for work with langchain + RAW  application?
#
# - 1. Model 1: qween3:4b
#     - ollama pull qwen3:8b
#
# - 2. Install LangChain integration:
#     - Activate environment:
#         - conda activate GenAI
#         - pip install -U langchain-ollama

# %%
""" 
                    Ollama
                       │
                       ▼
                  Qwen3 Model
                       │
       ┌───────────────┼───────────────┐
       ▼               ▼               ▼
      RAG            Tools          Agents
       │               │               │
       ▼               ▼               ▼
    Chroma          APIs/Tools      Tool Calling
       │               │               │
       └───────────────┼───────────────┘
                       ▼
                    LangChain
                       │
                       ▼
                Real Applications


"""

# %% [markdown]
# ### Verify ollama

# %%
from langchain_ollama import ChatOllama

print("ChatOllama is ready!")
# Out:
# c:\Users\kz\anaconda3\envs\GenAI\Lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.7.0) or chardet (7.6.0)/charset_normalizer (3.5.1) doesn't match a supported version!
#   warnings.warn(
# ChatOllama is ready!

# %% [markdown]
# ### LangChain + Ollama

# %%
from langchain_ollama import ChatOllama

model = ChatOllama(
    model="qwen3:8b",
    temperature=0
)

# %%
response = model.invoke(
    "What is machine learning?"
)

print(response.content)

# %% [markdown]
# ### Ollama + Prompt Templates

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_template(
    "Explain {topic} in simple terms."
)

chain = prompt | model

response = chain.invoke({
    "topic": "deep learning"
})

print(response.content)
